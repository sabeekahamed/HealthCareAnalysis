# %%
import pandas as pd
import numpy as np

# %%
lt1=[]
lt2=[]
lt3=[]
lt4=[]
lt5=[]
lt6=[]
lt7=[]
lt8=[]
lt1=np.random.randint(2, size=2797)
lt2=np.random.randint(2, size=2797)
lt3=np.random.randint(2, size=2797)
lt4=np.random.randint(2, size=2797)
lt5=np.random.randint(2, size=2797)
lt6=np.random.randint(1,5, size=2797)
lt7=np.random.randint(2, size=2797)
lt8=np.random.randint(2, size=2797)

# %%
df=pd.read_csv('Second.csv')

# %%
df['sputum']=lt1
df['x-ray']=lt2
df['genes']=lt3
df['cavitation']=lt4
df['hiv']=lt5
df['cd4+']=lt7
df['regimen']=lt6
df['cured']=lt8

# %%
df
# Out:
#          id  sputum  x-ray  genes  cavitation  hiv  cd4+  regimen  cured
# 0     10000       1      0      1           0    0     0        4      0
# 1     10001       1      1      1           0    0     0        1      1
# 2     10002       1      0      0           1    1     1        2      0
# 3     10003       1      0      0           1    1     1        4      0
# 4     10004       0      0      0           0    0     1        1      0
# 5     10005       1      1      0           0    1     1        1      1
# 6     10006       0      1      1           1    1     1        2      1
# 7     10007       1      0      0           0    1     1        2      0
# 8     10008       1      0      1           1    1     1        3      1
# 9     10009       0      1      1           1    0     1        3      0
# 10    10010       1      0      1           0    1     1        3      0
# 11    10011       1      1      1           1    0     0        1      0
# ...

# %%
df.to_csv("Result.csv",index=False)
