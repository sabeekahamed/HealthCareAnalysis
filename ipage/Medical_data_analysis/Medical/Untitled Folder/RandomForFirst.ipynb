# %%
import pandas as pd
import numpy as np

df=pd.read_csv('First.csv')
labels = np.array(df['tb'])
print(labels)
df=df.drop('tb',axis=1)
df=df.drop('id',axis=1)
df_list=list(df.columns)
df_list
tf=np.array(df)
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
train_df, test_df, train_labels, test_labels = train_test_split(tf, labels, test_size = 0.25, random_state = 42)
print('Training Features Shape:', train_df.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_df.shape)
print('Testing Labels Shape:', test_labels.shape)
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(train_df, train_labels);
# Use the forest's predict method on the test data
predictions = rf.predict(test_df)
# Calculate the absolute errors
errors = abs(predictions - test_labels)
# Print out the mean absolute error (mae)

print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Calculate mean absolute percentage error (MAPE)
#mape = 100 * (errors / test_labels)
# Calculate and display accuracy
#accuracy = 100 - np.mean(mape)
#print('Accuracy:', round(accuracy, 2))
# Import tools needed for visualization
from sklearn.tree import export_graphviz
import pydot
# Pull out one tree from the forest
tree = rf.estimators_[5]


# Import tools needed for visualization
#from sklearn.tree import export_graphviz 
#import pydot
# Pull out one tree from the forest
tree = rf.estimators_[5]
# Export the image to a dot file
export_graphviz(tree, out_file = 'tree.dot', feature_names = df_list, rounded = True, precision = 1)
# Use dot file to create a graph
(graph, ) = pydot.graph_from_dot_file('tree.dot')
# Write graph to a png file

graph.write_png('tree.png')
#graph.create_jpeg('tree.jpeg')
#1,0,1,1,1,1

print(df)
# Out:
# [1 1 0 ..., 0 0 1]
# Training Features Shape: (2097, 6)
# Training Labels Shape: (2097,)
# Testing Features Shape: (700, 6)
# Testing Labels Shape: (700,)
# Mean Absolute Error: 0.0 degrees.
#       smoke  fever  cough  chest_pain  age  wt_loss
# 0         0      0      0           1    4        1
# 1         1      1      1           0    4        1
# 2         0      0      1           0    4        0
# 3         1      0      1           0    4        0
# 4         1      1      0           1    3        0
# 5         1      0      0           1    4        1
# 6         0      1      1           1    1        1
# 7         1      0      1           1    1        0
# 8         1      1      1           0    4        0
# 9         1      1      0           0    1        0
# 10        1      1      1           1    3        0
# 11        1      1      0           1    2        1
# 12        1      1      1           1    1        0
# 13        0      0      0           1    2        0
# 14        1      1      0           0    1        1
# 15        1      0      1           0    2        0
# 16        0      0      0           1    4        0
# 17        0      1      1           0    5        0
# 18        0      1      0           0    1        1
# 19        0      0      1           1    3        0
# 20        0      1      1           0    5        0
# 21        0      0      0           0    4        0
# 22        0      0      1           1    3        0
# 23        0      1      1           0    1        1
# 24        0      0      0           1    2        0
# 25        0      0      0           0    2        1
# 26        1      1      1           1    2        0
# 27        0      1      0           1    2        1
# 28        1      0      0           1    3        0
# 29        0      1      0           1    1        1
# ...     ...    ...    ...         ...  ...      ...
# 2767      1      0      1           1    5        1
# 2768      0      1      0           1    1        0
# 2769      1      1      1           0    3        0
# 2770      1      1      1           1    4        1
# 2771      0      1      1           0    1        0
# 2772      1      1      0           0    2        1
# 2773      0      1      1           0    4        0
# 2774      1      1      1           1    2        0
# 2775      1      0      0           1    3        0
# 2776      1      1      0           1    2        0
# 2777      0      1      0           1    3        1
# 2778      0      0      0           1    2        0
# 2779      1      0      1           0    2        1
# 2780      1      1      1           1    3        1
# 2781      1      1      0           1    1        0
# 2782      1      1      1           1    5        1
# 2783      1      1      1           1    5        0
# 2784      1      1      0           0    3        0
# 2785      1      1      1           0    4        0
# 2786      1      1      1           0    2        0
# 2787      1      0      0           1    1        0
# 2788      0      1      1           1    5        1
# 2789      0      0      1           1    5        0
# 2790      1      1      1           1    3        0
# 2791      0      1      0           1    1        0
# 2792      0      1      1           0    3        0
# 2793      1      1      0           0    5        1
# 2794      0      0      1           0    3        1
# 2795      1      0      0           1    2        0
# 2796      1      1      0           1    5        0
#
# [2797 rows x 6 columns]

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('First.csv')
labels = np.array(df['tb'])
tk=df.tb.values
df=df.drop('tb',axis=1)
df_list=list(df.columns)
df_list
df=df.drop('id',axis=1)
df_list1=list(df.columns)
tf=np.array(df)
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
train_df, test_df, train_labels, test_labels = train_test_split(tf, labels, test_size = 0.25, random_state = 42)
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
rf.fit(train_df, train_labels);
predictions = rf.predict([[0,0,0,1,0,0]])      #inputs
if(predictions):
    print("you need to take test:")
else:
    print("You doesnt affected by tb")
# Out:
# You doesnt affected by tb

# %%
# Import tools needed for visualization
from sklearn.tree import export_graphviz 
import pydot
# Pull out one tree from the forest
tree = rf.estimators_[200]
# Export the image to a dot file
export_graphviz(tree, out_file = 'treess.dot', feature_names = df_list1, rounded = True, precision = 1)
# Use dot file to create a graph
(graph, ) = pydot.graph_from_dot_file('treess.dot')
#
import pydotplus

pydot_graph = pydotplus.graph_from_dot_file("treess.dot")
from IPython.display import Image

Image(pydot_graph.create_png())

# %%
import pandas as pd 
# %matplotlib inline 
import matplotlib.pyplot as plt 
plt.style.use('ggplot') 
X = df# drop target variable 
y1 =tk
#pd.DataFrame.hist(df, figsize = [15,15]); 
plt.boxplot(X)

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('First.csv')
labels = np.array(df['tb'])
print(labels)
df=df.drop('tb',axis=1)
df=df.drop('id',axis=1)
df_list=list(df.columns)
df_list
tf=np.array(df)
from sklearn.model_selection import train_test_split
train_df, test_df, train_labels, test_labels = train_test_split(tf, labels, test_size = 0.25, random_state = 42)
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
rf.fit(train_df, train_labels);
predictions = rf.predict(test_df)
errors = abs(predictions - test_labels)
from sklearn.tree import export_graphviz
import pydot
tree = rf.estimators_[5]
export_graphviz(tree, out_file = 'tree.dot', feature_names = df_list, rounded = True, precision = 1)
(graph, ) = pydot.graph_from_dot_file('tree.dot')
import pydotplus
pydot_graph = pydotplus.graph_from_dot_file("tree.dot")
from IPython.display import Image

Image(pydot_graph.create_png())
# Out:
# ['id', 'smoke', 'fever', 'cough', 'chest_pain', 'age', 'wt_loss']
