# %%
import pandas as pd

# %%
pf=pd.read_csv("SN1727.csv",encoding = 'ISO-8859-1',skip_blank_lines=True)
pf_col=pf.columns
pf['Constituents/Unit']
#print(pf['Name'].skip_blank_lines=True)
#print(pf['Name'])#,skip_blank_lines=True)
lt3=[]
k=0
for i in pf['Name']:
    if(k==0):
        lt3.append(i)
        k=k+1
    elif(k<3):
        k=k+1
    else:
        k=0
lt1=[]
k=0
for i in pf['S/N']:
    if(k==0):
        lt1.append(i)
        k=k+1
    elif(k<3):
        k=k+1
    else:
        k=0
lt2=[]
k=0
for i in pf['Manufacturer']:
    if(k==0):
        lt2.append(i)
        k=k+1
    elif(k<3):
        k=k+1
    else:
        k=0
lt4=[]
k=0
for i in pf['Type']:
    if(k==0):
        lt4.append(i)
        k=k+1
    elif(k<3):
        k=k+1
    else:
        k=0
lt5=[]
k=0
for i in pf['Unit(Dose)']:
    if(k==0):
        lt5.append(i)
        k=k+1
    elif(k<3):
        k=k+1
    else:
        k=0
print(pf)
# Out:
#      S/N                       Manufacturer                             Name  \
# 0    1.0     Overseas Health Care Pvt. Ltd.      RHZ Kid Forte (500+100+150)
# 1    NaN                                NaN                              NaN
# 2    NaN                                NaN                              NaN
# 3    2.0            Lupin Laboratories Ltd.  Rinizide Forte DT (500+100+150)
# 4    NaN                                NaN                              NaN
# 5    NaN                                NaN                              NaN
# 6    3.0               Osho Pharma Pvt.Ltd.             Orif 3 (500+100+150)
# 7    NaN                                NaN                              NaN
# 8    NaN                                NaN                              NaN
# 9    4.0              Hamax Pharmaceuticals            Rinex Z (500+100+150)
# 10   NaN                                NaN                              NaN
# ...

# %%
lt6=[]
k=0
temp=""
p=0
for i in pf['Constituents/Unit']:
    if(k<3):
        temp=temp+i+'+'
        k=k+1
    else:
        k=0
        lt6.append(temp+i)
        temp=""

# %%
lt7=[]
lt8=[]
lt9=[]
k=0
for i in pf['Package unit']:
    if(k==0):
        lt7.append(i)
        k=k+1
    elif(k<3):
        k=k+1
    else:
        k=0

k=0
for i in pf['Price(In Rs.)']:
    if(k==0):
        lt8.append(i)
        k=k+1
    elif(k<3):
        k=k+1
    else:
        k=0
for i in pf['Price/Unit (In Rs.)']:
    if(k==0):
        lt9.append(i)
        k=k+1
    elif(k<3):
        k=k+1
    else:
        k=0

# %%
lt1.count
# Out:
# <function list.count>

# %%
k=0
for i in lt3:
    k=k+1
print(k)
# Out:
# 13

# %%
pn=pd.DataFrame({'S/N':lt1,'Manufacturer':lt2,'Name':lt3,'Type':lt4,'Unit(Dose)':lt5,'Constituents/Unit':lt6,'Package unit':lt7,'Price(In Rs.)':lt8,'Price/Unit (In Rs.)':lt9})
pn
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-9519b15a5075> in <module>()
# ----> 1 pn=pd.DataFrame({'S/N':lt1,'Manufacturer':lt2,'Name':lt3,'Type':lt4,'Unit(Dose)':lt5,'Constituents/Unit':lt6,'Package unit':lt7,'Price(In Rs.)':lt8,'Price/Unit (In Rs.)':lt9})
#       2 pn
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     273                                  dtype=dtype, copy=copy)
#     274         elif isinstance(data, dict):
# --> 275             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     276         elif isinstance(data, ma.MaskedArray):
#     277             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
# ...
