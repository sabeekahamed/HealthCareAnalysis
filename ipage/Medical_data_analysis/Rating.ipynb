# %%
import pandas as pd

# %%
df=pd.read_csv("SN32.csv",encoding = 'ISO-8859-1')

# %%
df
# Out:
#     S/N                              Manufacturer                      Name  \
# 0     1                Merind Ltd (Wockhardt Ltd)         Deca Forte (1 mg)
# 1     2  Pfizer Limited (Pharmacia India Pvt Ltd)  Betacortril Forte (1 mg)
# 2     3     Glaxo Smithkline Pharmaceuticals Ltd.        Betnecip FC (1 mg)
# 3     4     Glaxo Smithkline Pharmaceuticals Ltd.        Betnelan FC (1 mg)
# 4     5                         Ind-Swift Limited       Stemin Forte (1 mg)
# 5     6                                 Medopharm         Betsone DS (1 mg)
# 6     7                   Lupin Laboratories Ltd.            Solubet (1 mg)
# 7     8     Glaxo Smithkline Pharmaceuticals Ltd.     Betnesol Forte (1 mg)
# 8     9                   Comed Chemicals Pvt Ltd        Belar Forte (1 mg)
# 9    10                            Micro Labs Ltd          Cortil FC (1 mg)
# 10   11                 Rax Health Care Pvt. Ltd.            Betarax (1 mg)
# ...

# %%
rating=1/22

# %%
a=int(input("Is recommended(1) or not(0):"))
# Out:
# Is recommended(1) or not(0):0

# %% [markdown]
# # if(a==1):
#     rating=rating+(1/22)

# %% [markdown]
# # df["S/N"].count()

# %%
if(a==1):
    rating=rating+(1/df["S/N"].count())

# %%
rating
# Out:
# 0.18181818181818182

# %%
# Out:
# 0.045454545454545456
